# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
file_path = 'seattle-weather.csv'
weather_data = pd.read_csv(file_path)
weather_data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
weather_data_cleaned = weather_data.drop(columns=['date'])
label_encoder = LabelEncoder()
weather_data_cleaned['weather'] = label_encoder.fit_transform(weather_data_cleaned['weather'])
weather_data_cleaned.head()
# Out:
#    precipitation  temp_max  temp_min  wind  weather
# 0            0.0      12.8       5.0   4.7        0
# 1           10.9      10.6       2.8   4.5        2
# 2            0.8      11.7       7.2   2.3        2
# 3           20.3      12.2       5.6   4.7        2
# 4            1.3       8.9       2.8   6.1        2

# %%
X = weather_data_cleaned.drop(columns=['weather'])
y = weather_data_cleaned['weather']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
print("Training set size:", X_train.shape)
print("Testing set size:", X_test.shape)
# Out:
# Training set size: (1022, 4)
# Testing set size: (439, 4)

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
classification_rep = classification_report(y_test, y_pred, target_names=label_encoder.classes_)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.8291571753986332
# Classification Report:
#                precision    recall  f1-score   support
#
#      drizzle       0.29      0.12      0.17        16
#          fog       0.00      0.00      0.00        30
#         rain       0.97      0.89      0.93       193
#         snow       0.50      0.38      0.43         8
#          sun       0.75      0.98      0.85       192
#
#     accuracy                           0.83       439
#    macro avg       0.50      0.47      0.48       439
# weighted avg       0.78      0.83      0.79       439
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
